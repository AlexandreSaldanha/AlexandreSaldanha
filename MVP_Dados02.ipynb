# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexandreSaldanha/AlexandreSaldanha/blob/main/MVP_Dados02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **1. Definição do Problema**

# %%
# Configuração para não exibir os warnings
import warnings
warnings.filterwarnings("ignore")

# Importação de pacotes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm

# %% [markdown]
# # **2. Carregando Dados**

# %%
# Informa a URL de importação do dataset
url = "https://raw.githubusercontent.com/AlexandreSaldanha/AlexandreSaldanha/main/Expectativa_Vida"

# Lê o arquivo
dataset = pd.read_csv(url, delimiter=',')

# %%
# Mostra as 10 primeiras linhas do dataset
dataset.head(10)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
# 9  Afghanistan  2006  Developing              57.3            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# ...

# %%
# Mostra as 10 últimas linhas do dataset
dataset.tail(10)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 2928  Zimbabwe  2009  Developing              50.0            587.0
# 2929  Zimbabwe  2008  Developing              48.2            632.0
# 2930  Zimbabwe  2007  Developing              46.6             67.0
# 2931  Zimbabwe  2006  Developing              45.4              7.0
# 2932  Zimbabwe  2005  Developing              44.6            717.0
# 2933  Zimbabwe  2004  Developing              44.3            723.0
# 2934  Zimbabwe  2003  Developing              44.5            715.0
# 2935  Zimbabwe  2002  Developing              44.8             73.0
# 2936  Zimbabwe  2001  Developing              45.3            686.0
# 2937  Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 2928             30     4.64                1.040021         73.0       853
# ...

# %%
# first i see some column name with empty space i will fixed it to ease of use

dataset.columns = dataset.columns.str.strip()

# %% [markdown]
# # **3. Análise** **de Dados**

# %%
# Mostra as informações do dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
# Mostra as dimensões do dataset
dataset.shape
# Out:
# (2938, 22)

# %%
# Mostra a distribuição do dataset e quantidade de países por satus, além da frequencia do paises em anos
dataset['Country'].groupby(dataset.Status).describe()
# Out:
#            count unique          top freq
# Status
# Developed    512     32    Australia   16
# Developing  2426    161  Afghanistan   16

# %%
###
def pie_plot(Status):

  plt.pie(dataset[Status].value_counts(), labels = dataset[Status].value_counts().index, shadow = True, autopct = "%1.1f%%")

# %%
# Mostra o Gráfico de pizza com a distribuição percentual dos status
pie_plot('Status')

# %%
# cria função que visualiza colunas numéricas usando box plot
def box_plot(x_axis = None, y_axis = None):

    sns.boxplot(x = x_axis, y = y_axis, data = dataset)
    plt.xlabel(x_axis)
    plt.ylabel("FRQ")
    plt.show()

# %%
# Mostra a o boxplot da função criada
plt.figure(figsize=(10,5))

box_plot(x_axis = "Status", y_axis = "Life expectancy")

# %%
dataset01 = dataset.query('Status == "Developed"')

# %%
dataset01.shape
# Out:
# (512, 22)

# %%
dataset02.shape
# Out:
# (2426, 22)

# %%
dataset02 = dataset.query('Status == "Developing"')

# %%
# see the impact of "year" on "Life Expectancy"

# set figure size
plt.figure(figsize=(10,5))

sns.lineplot(x = 'Year', y = 'Life expectancy', data = dataset02, marker = 'o' ,errorbar=('ci', False))
sns.lineplot(x = 'Year', y = 'Life expectancy', data = dataset01, marker = 'o' ,errorbar=('ci', False))

plt.show()

# %%
dataset01.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count   512.000000       512.000000       512.000000     512.000000
# mean   2007.500000        79.197852        79.685547       1.494141
# std       4.614281         3.930942        47.877583       4.585774
# min    2000.000000        69.900000         1.000000       0.000000
# 25%    2003.750000        76.800000        58.000000       0.000000
# 50%    2007.500000        79.250000        73.000000       0.000000
# 75%    2011.250000        81.700000        96.000000       1.000000
# max    2015.000000        89.000000       229.000000      28.000000
#
#           Alcohol  percentage expenditure  Hepatitis B       Measles  \
# count  484.000000              512.000000   339.000000    512.000000
# mean     9.826736             2703.600380    88.041298    499.005859
# std      2.765858             3824.200588    20.489240   2529.084588
# min      0.010000                0.000000     2.000000      0.000000
# ...

# %%
dataset02.describe()
# Out:
#               Year  Life expectancy  Adult Mortality  infant deaths  \
# count  2426.000000      2416.000000      2416.000000    2426.000000
# mean   2007.522671        67.111465       182.833195      36.384171
# std       4.614690         9.006092       127.974557     128.942509
# min    2000.000000        36.300000         1.000000       0.000000
# 25%    2004.000000        61.100000        92.000000       1.000000
# 50%    2008.000000        69.000000       163.000000       6.000000
# 75%    2012.000000        74.000000       253.000000      28.000000
# max    2015.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  2260.000000             2426.000000  2046.000000    2426.000000
# mean      3.484119              323.470285    79.763930    2824.926216
# std       3.347537              846.655356    25.564884   12528.811419
# ...

# %% [markdown]
# # **Analise Univariada**

# %%
# Histograma
dataset01.hist(figsize = (20,15))
plt.show()

# %%
# Histograma
dataset02.hist(figsize = (20,15))
plt.show()

# %%
# Density Plot
dataset01.plot(kind = 'density', subplots = True, layout = (5,4), sharex = False, figsize = (20,15))
plt.show()

# %%
# Density Plot
dataset02.plot(kind = 'density', subplots = True, layout = (5,4), sharex = False, figsize = (20,15))
plt.show()

# %%
# Boxplot
dataset01.plot(kind = 'box', subplots = True, layout = (5,4), sharex = False, sharey = False, figsize = (15,10))
plt.show()

# %%
# Boxplot
dataset02.plot(kind = 'box', subplots = True, layout = (5,4), sharex = False, sharey = False, figsize = (15,10))
plt.show()

# %% [markdown]
# # **Análise Multivariada**

# %%
# Matriz de Correlação com Seaborn
plt.figure(figsize = (15,10))
sns.heatmap(dataset01.corr(), annot=True, cmap='RdBu', vmin=-1, vmax=1);

# %%
# Matriz de Correlação com Seaborn
plt.figure(figsize = (15,10))
sns.heatmap(dataset02.corr(), annot=True, cmap='RdBu', vmin=-1, vmax=1);

# %%
# create list of numerical column

numerical_colum = dataset01.select_dtypes(exclude = object).columns.tolist()
numerical_colum.remove("Year") # remove year column from list

# %%
# remove target column

numerical_colum.remove("Life expectancy")

# %%
def create_scatterplot(x_axis, column_name):

    # 1- set figure size
    plt.figure(figsize=(15, 20))

    # 2- loop over services list to plot columns
    for index, col in enumerate(column_name):
        plt.subplot((len(column_name) + 1) // 2, 2, index + 1) # create sub-plot

        sns.scatterplot(x = x_axis, y = col, data = dataset01)

        plt.title(col) # set title to each plot
        plt.xlabel("") # replace x label with empty string
        plt.ylabel("") # replace y label with empty string


 # 3- set layout between two plots
    plt.tight_layout(pad = 2)

    plt.show()

# %%
create_scatterplot("Life expectancy", numerical_colum)
